# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

# Add the project root to the Python path
project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Fewer imports needed in the notebook
from python_utils.ssb_api import SSBClient
from IPython.display import display

# 1. Initialize the client with just the table ID
client = SSBClient(table_id="14380")

# 2. Build the query (this logic stays in the notebook)
variable_codes = client.get_variable_codes()
print(variable_codes)
query = {
    "query": [
        {"code": code, "selection": {"filter": "all", "values": ["*"]}} for code in variable_codes
    ],
    "response": {"format": "json-stat2"}
}

# 3. Get th0e DataFrame with one simple method call
df = client.get_dataframe(query)

display(df)

# 4. (Optional) You can now easily save this data for later use
# client.download_to_parquet(query, file_path="my_data.parquet")
# Out:
# ['Region', 'Smaviltjakt', 'ContentsCode', 'Tid']
#                  region     småvilt statistikkvariabel intervall (år)  \
# 0           Hele landet       I alt      Felte småvilt      2023-2024
# 1           Hele landet    Storfugl      Felte småvilt      2023-2024
# 2           Hele landet     Orrfugl      Felte småvilt      2023-2024
# 3           Hele landet      Lirype      Felte småvilt      2023-2024
# 4           Hele landet   Fjellrype      Felte småvilt      2023-2024
# ...                 ...         ...                ...            ...
# 41579  Uoppgitt kommune    Villmink      Felte småvilt      2023-2024
# 41580  Uoppgitt kommune         Mår      Felte småvilt      2023-2024
# 41581  Uoppgitt kommune     Mårhund      Felte småvilt      2023-2024
# 41582  Uoppgitt kommune  Vaskebjørn      Felte småvilt      2023-2024
# 41583  Uoppgitt kommune    Røyskatt      Felte småvilt      2023-2024
#
#           value
# 0      298920.0
# 1        5920.0
# 2       11960.0
# ...

# %%
display(df[df["småvilt"].isin(["Fjellrype", "Lirype"])])
# Out:
#                     region    småvilt statistikkvariabel intervall (år)  \
# 3              Hele landet     Lirype      Felte småvilt      2023-2024
# 4              Hele landet  Fjellrype      Felte småvilt      2023-2024
# 49                 Østfold     Lirype      Felte småvilt      2023-2024
# 50                 Østfold  Fjellrype      Felte småvilt      2023-2024
# 95                  Halden     Lirype      Felte småvilt      2023-2024
# ...                    ...        ...                ...            ...
# 41450  Ikke bosatt i Norge  Fjellrype      Felte småvilt      2023-2024
# 41495       Uoppgitt fylke     Lirype      Felte småvilt      2023-2024
# 41496       Uoppgitt fylke  Fjellrype      Felte småvilt      2023-2024
# 41541     Uoppgitt kommune     Lirype      Felte småvilt      2023-2024
# 41542     Uoppgitt kommune  Fjellrype      Felte småvilt      2023-2024
#
#          value
# 3      80290.0
# 4      39320.0
# 49         0.0
# 50         0.0
# 95         0.0
# ...

# %%
client.get_metadata()
# Out:
# {'title': '14380: Felte småvilt, etter region, småvilt, statistikkvariabel og intervall (år)',
#  'variables': [{'code': 'Region',
#    'text': 'region',
#    'values': ['0',
#     '31',
#     '3101',
#     '3103',
#     '3105',
#     '3107',
#     '3110',
#     '3112',
#     '3114',
#     '3116',
#     '3118',
#     '3120',
#     '3122',
#     '3124',
#     '32',
#     '3201',
#     '3203',
#     '3205',
#     '3207',
#     '3209',
#     '3212',
#     '3214',
#     '3216',
#     '3218',
#     '3220',
#     '3222',
#     '3224',
#     '3226',
#     '3228',
#     '3230',
#     '3232',
#     '3234',
#     '3236',
#     '3238',
#     '3240',
#     '3242',
#     '30',
#     '01',
#     '3001',
#     '3002',
#     '3003',
#     '3004',
#     '3005',
#     '3006',
#     '3007',
#     '3011',
#     '3012',
#     '3013',
#     '3014',
#     '3015',
#     '3016',
#     '3017',
#     '3018',
#     '3019',
#     '3020',
#     '3021',
#     '3022',
#     '3023',
#     '3024',
#     '3025',
# ...
